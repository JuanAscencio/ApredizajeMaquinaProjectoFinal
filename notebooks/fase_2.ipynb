# %% [markdown]
# ***Fase 2 - Clasificación inicial con MLP***
#
# Objetivo: Entrenar el primer modelo MLP usando TODAS las características excepto "Longitud".

# %% [markdown]
# 1. Crear modelo MLP

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(
    hidden_layer_sizes=(100,50),
    activation='tanh',
    solver='sgd',
    max_iter=3800,
    random_state=42
)

# %% [markdown]
# 2. Stratified K-Fold

# %%
kfold = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

scores = cross_val_score(
    mlp,
    X_scaled,
    y,
    cv=kfold,
    scoring='accuracy'
)

print("Accuracies:", scores)
print("Accuracy promedio:", scores.mean())

# %% [markdown]
# 3. Metricas

# %%
mlp.fit(X_scaled, y)

# %% [markdown]
# 4. Matriz de confusión

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

mlp.fit(X_train, y_train)

y_pred = mlp.predict(X_test)


cm = confusion_matrix(y_test, y_pred, normalize='true')

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='.2f', cmap='Blues')

plt.title("Matriz de confusión")
plt.xlabel("Predicción")
plt.ylabel("Valor real")

plt.show()

# %% [markdown]
# 5. Curva de aprendizaje

# %%
plt.figure(figsize=(8,5))
plt.plot(mlp.loss_curve_)
plt.title("Curva de aprendizaje")
plt.xlabel("Iteraciones")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

# %% [markdown]
# 6. Probar hiperparámetros
#
#     Probar varias configuraciones

# %% [markdown]
# * Arquitecturas

# %% [raw]
# (50,)
# (100,)
# (100,50)
# (200,100)

# %% [markdown]
# * Activaciones

# %% [raw]
# relu
# tanh
# logistic

# %% [markdown]
# * Solvers

# %% [raw]
# adam
# sgd
# lbfgs

# %% [markdown]
# **Crear una tabla**
#
# | Arquitectura | Activación | Accuracy |
# |--------------|------------|-----------|
# | (50,)        | relu    | 0.82   |
# | (100,)       | relu    | 0.86   |
# | (100,50)     | tanh    | 0.88   |

# %% [markdown]
# **Qué debes analizar en esta fase**
#
#
# **En el reporte PDF**
#
# Debes explicar:
#
# 1. Qué hiperparámetros funcionaron mejor
# 1. Cómo cambia el accuracy
# 1. Si existe overfitting
# 1. Cómo se comporta la curva de aprendizaje
# 1. Comparación inicial con el artículo
