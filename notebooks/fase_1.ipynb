# %% [markdown]
# ***Fase 1 - Preprocesamiento***
#
# Objetivo: Preparar el dataset para el entrenamiento del MLP.

# %% [markdown]
# 1. Importar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# 2. Cargar dataset

# %%
ruta = "../data/DataSet_completo.xlsx"

df = pd.read_excel(ruta)

print("- Head")
print(df.head())
print("\n- Shape")
print(df.shape)
print("\n- Info")
print(df.info())

# %% [markdown]
# 3. Verificar valores nulos

# %%
print(df.isnull().sum())

#Si fuera el caso
df = df.dropna()

# %% [markdown]
# 4. Eliminar caractertíca dominante

# %%
#El proyecto exige eliminar "Longitud"
df.drop(columns=["Longitud"], inplace = True)
print(df.info())

# %% [markdown]
# 5. Separar variables

# %%
X = df.drop(columns=["Clase"])
y = df["Clase"]

# %% [markdown]
# 6. Estandarización

# %%
#Usaremos Z-Score con StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 7. Visualización inicial

# %% [markdown]
# - Distribución de clases

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=y)
plt.title("Distribución de clases")
plt.show()

# %% [markdown]
# - Matriz de correlación inicial

# %%
corr = X.corr()

plt.figure(figsize=(16,12))
sns.heatmap(corr, cmap="coolwarm")
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# **Qué debes analizar en esta fase**
#
#
# **En el reporte PDF**
#
# Debes explicar:
#
# 1. Cantidad de muestras
# 1. Número de características
# 1. Qué representa cada tipo de característica
# 1. Por qué se eliminó “Longitud”
# 1. Si existen variables muy correlacionadas
# 1. Balance de clases
